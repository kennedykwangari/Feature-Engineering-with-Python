# %% [markdown]
# ## Mapping Geograph Data in Python

# %%
# here we will impor the libraries used for machine learning
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph 
import seaborn as sns # used for plot interactive graph. I like it most for plot
# %matplotlib inline

from sklearn.linear_model import LogisticRegression # to apply the Logistic regression
from sklearn.model_selection import train_test_split,GridSearchCV  # to split the data into two parts
from sklearn.model_selection import KFold, cross_val_score  # use for K- fold cross validation
from sklearn.model_selection import GridSearchCV# for tuning parameter
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.ensemble import RandomForestClassifier # for random forest classifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm # for Support Vector Machine
from sklearn import metrics # for the check the error and accuracy of the model

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold

from sklearn.metrics import roc_curve, precision_recall_curve, auc, make_scorer, recall_score, accuracy_score,average_precision_score, precision_score, confusion_matrix, classification_report

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score,confusion_matrix, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score

from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
# Imported Libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt  #
import seaborn as sns  #
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib.patches as mpatches
import time

# Classifier Libraries
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import collections


# Other Libraries
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
from collections import Counter
from sklearn.model_selection import KFold, StratifiedKFold
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the Train and Test Sets

train= pd.read_csv('DatasetModel.csv')
test  = pd.read_csv('702ddfc5-68cd-4d1d-a0de-f5f566f76d91.csv')
full_data = [train, test]
print (dataset.info())

# %%
print('This dataset contains ',dataset.shape[0],'rows')
print('This dataset contains ',dataset.shape[1],'columns')
# Out:
# ('This dataset contains ', 59400, 'rows')
# ('This dataset contains ', 46, 'columns')

# %%
dataset.head(3)
# Out:
#       id  amount_tsh        funder  gps_height     installer     wpt_name  \
# 0  69572      6000.0         Roman        1390         Roman         none
# 1   8776         0.0       Grumeti        1399       GRUMETI     Zahanati
# 2  34310        25.0  Lottery Club         686  World vision  Kwa Mahundi
#
#    num_private          basin subvillage   region  ...  waterpoint_type_group  \
# 0            0     Lake Nyasa   Mnyusi B   Iringa  ...     communal standpipe
# 1            0  Lake Victoria    Nyamara     Mara  ...     communal standpipe
# 2            0        Pangani    Majengo  Manyara  ...     communal standpipe
#
#    status_group year_recorded month_recorded  week_of_year_recorded  \
# 0    functional          2011              3                     11
# 1    functional          2013              3                     10
# 2    functional          2013              2                      9
#
#   day_of_week_recorded day_of_year_recorded quarter_of_date_recorded  \
# ...

# %%
# importing libraries

import geopandas as gpd  # To create GeodataFrame
from shapely.geometry import Point, Polygon  # Shapely for converting latitude/longtitude to geometry
# %matplotlib inline
import pandas as pd # Reading csv file

# %%
# Read in the data
full_data = gpd.read_file("places.shp")

# View the first five rows of the data
full_data.head()
# Out:
#      osm_id        name     type  population                   geometry
# 0  27251888      Nungwi     town         NaN  POINT (39.29922 -5.72635)
# 1  27251889     Kilindi  village         NaN  POINT (39.28754 -5.87489)
# 2  27251989     Mahonda     town         NaN  POINT (39.24995 -5.98834)
# 3  27252328      Bububu  village         NaN  POINT (39.23334 -6.09252)
# 4  27252361  Stone Town     city         NaN  POINT (39.19330 -6.16344)

# %%
full_data.plot(alpha=0.4)

# %%
f, ax = plt.subplots(1)
ax = full_data.plot(axes=ax)
ax.set_axis_off()
plt.show()

# %%
f, ax = plt.subplots(1)
ax = full_data.plot(axes=ax)
f.suptitle('Water Pump Location')
plt.show()

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
ax = full_data.plot(axes=ax)
f.suptitle('Water Pump Location')
plt.show()

# %%
full_data.loc[0, 'geometry']

# %%
f, ax = plt.subplots(1, figsize=(12, 4))
ax = full_data.plot(axes=ax)
plt.show()

# %%
# Setup figure and axis
f, ax = plt.subplots(1)
# Add layer of polygons on the axis, set fill color (`facecolor`) and boundary
# color (`edgecolor`)
full_data.plot(linewidth=0.1, facecolor='red', edgecolor='grey', ax=ax)
# Display
plt.show()

# %%
# Setup figure and axis
f, ax = plt.subplots(1)
# Add a layer with polygons on to axis `ax`
full_data.plot(ax=ax, facecolor='grey', edgecolor='white', linewidth=0.2)
# Add a layer with lines on top in axis `ax`
rwy_tun.plot(ax=ax, color='red')
# Display
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-43-b3e3f74ddc1b> in <module>()
#       4 full_data.plot(ax=ax, facecolor='grey', edgecolor='white', linewidth=0.2)
#       5 # Add a layer with lines on top in axis `ax`
# ----> 6 rwy_tun.plot(ax=ax, color='red')
#       7 # Display
#       8 plt.show()
#
# NameError: name 'rwy_tun' is not defined

# %%
# Set up figure and axes
f, ax = plt.subplots(1)
# Plot polygon layer
full_data.plot(ax=ax, facecolor='grey', alpha=0.25, linewidth=0.1)
# Plot line layer
rwy_tun.plot(ax=ax, color='green', linewidth=3)
# Save figure to a PNG file
plt.savefig('liverpool_railway_tunels.png')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-44-60c8bb4f98bc> in <module>()
#       4 full_data.plot(ax=ax, facecolor='grey', alpha=0.25, linewidth=0.1)
#       5 # Plot line layer
# ----> 6 rwy_tun.plot(ax=ax, color='green', linewidth=3)
#       7 # Save figure to a PNG file
#       8 plt.savefig('liverpool_railway_tunels.png')
#
# NameError: name 'rwy_tun' is not defined

# %%
full_data.plot()

# %%
import geopandas
from geopandas import GeoDataFrame, GeoSeries
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import matplotlib.cm as cm
# %matplotlib inline
import seaborn as sns
from shapely.geometry import Point, Polygon
import numpy as np
import googlemaps
from datetime import datetime
plt.rcParams["figure.figsize"] = [8,6]

# %%
# Read in the data
full_data = gpd.read_file("places.shp")

# View the first five rows of the data
full_data.head()

# %%
type(full_data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data = full_data.loc[:, ["name", "type", "geometry"]].copy()

# %%
# How many lands of each type are there?

data['type'].value_counts()
# Out:
# village             1103
# hamlet               195
# town                 180
# suburb                65
# city                  22
# locality              13
# isolated_dwellin      11
# island                 4
# neighbourhood          3
# country                1
# at water way           1
# Mambo - Mtae - L       1
# national_park          1
# county                 1
# Name: type, dtype: int64

# %%
# Select Pumps that fall in the City Category

city_pumps = data.loc[data['type'].isin(['town', 'suburb','city' ])].copy()
city_pumps.head()
# Out:
#              name  type                   geometry
# 0          Nungwi  town  POINT (39.29922 -5.72635)
# 2         Mahonda  town  POINT (39.24995 -5.98834)
# 4      Stone Town  city  POINT (39.19330 -6.16344)
# 9   Dar es Salaam  city  POINT (39.28038 -6.81427)
# 10       Kiwengwa  town  POINT (39.37425 -5.99141)

# %%
city_pumps.plot()

# %%
landuse

# %%
# Read in the data
land_data = gpd.read_file("landuse.shp")

# View the first five rows of the data
land_data.head()
# Out:
#      osm_id                            name              type  \
# 0  25108344           Anadil Burhani Ground  recreation_groun
# 1  25108362  Gymkhanna Ground & Golf Course  recreation_groun
# 2  25108364                  Shia Graveyard          cemetery
# 3  25109115                            None  recreation_groun
# 4  25116638                            None       residential
#
#                                             geometry
# 0  POLYGON ((39.28220 -6.80922, 39.28245 -6.80879...
# 1  POLYGON ((39.28775 -6.80435, 39.28755 -6.80473...
# 2  POLYGON ((39.28317 -6.81374, 39.28379 -6.81416...
# 3  POLYGON ((39.27918 -6.79677, 39.27953 -6.79624...
# 4  POLYGON ((39.21308 -6.10067, 39.22060 -6.09511...

# %%
# Read in the data
build = gpd.read_file("buildings.shp")

# View the first five rows of the data
build.head()
# Out:
#      osm_id            name    type  \
# 0  23360957            None  hangar
# 1  25103382        Old Fort  museum
# 2  25929297  Ferry Terminal    None
# 3  25930722        Oxfam GB  office
# 4  31791613            None    None
#
#                                             geometry
# 0  POLYGON ((39.19923 -6.87053, 39.19871 -6.87054...
# 1  POLYGON ((39.18932 -6.16108, 39.18944 -6.16132...
# 2  POLYGON ((39.28854 -6.81962, 39.28862 -6.81970...
# 3  POLYGON ((39.25566 -6.76493, 39.25593 -6.76463...
# 4  POLYGON ((39.28749 -6.81760, 39.28756 -6.81769...

# %%
# Define a base map with county boundaries
ax = full_data.plot(figsize=(10,10), color='none', edgecolor='gainsboro', zorder=2)

# Add wild lands, campsites, and foot trails to the base map
full_data.plot(color='red', ax=ax)
land.plot(color='red', markersize=2, ax=ax)
build.plot(color='green', markersize=2, ax=ax)

# %%
import pandas as pd
from pandas.api.types import is_string_dtype, is_numeric_dtype
import numpy as np
import re
import requests
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy import stats
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

import warnings
import types

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Detecting and Treating Missing Values

# %%
# Check for unique values
dataset['permit'].unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
dataset['scheme_name'].unique()
# Out:
# array(['Roman', nan, 'Nyumba ya mungu pipe scheme', ..., 'BL Nsherehehe',
#        'Magati  gravity spri', 'Mtawanya'], dtype=object)

# %%
# Fill NaN value with the mode. 
dataset['scheme_name'].fillna(dataset['scheme_name'].mode()[0], inplace=True)

# %%
# Fill NaN value with the mode. 
dataset['permit'].fillna(dataset['permit'].mode()[0], inplace=True)

# %%
# Check for any NaN values left.
dataset['permit'].unique()
# Out:
# array([False,  True])

# %%
dataset['public_meeting'].unique()
# Out:
# array([True, nan, False], dtype=object)

# %%
dataset['public_meeting'].fillna(dataset['public_meeting'].mode()[0], inplace=True)

# %%
dataset['public_meeting'].unique()
# Out:
# array([ True, False])

# %%
dataset['subvillage'].unique()
# Out:
# array(['Mnyusi B', 'Nyamara', 'Majengo', ..., 'Itete B', 'Maore Kati',
#        'Kikatanyemba'], dtype=object)

# %%
dataset['subvillage'].fillna(dataset['subvillage'].mode()[0], inplace=True)

# %%
dataset['scheme_management'].unique()
# Out:
# array(['VWC', 'Other', nan, 'Private operator', 'WUG', 'Water Board',
#        'WUA', 'Water authority', 'Company', 'Parastatal', 'Trust', 'SWC',
#        'None'], dtype=object)

# %%
dataset['scheme_management'].fillna(dataset['scheme_management'].mode()[0], inplace=True)

# %%
dataset['scheme_management'].unique()
# Out:
# array(['VWC', 'Other', 'Private operator', 'WUG', 'Water Board', 'WUA',
#        'Water authority', 'Company', 'Parastatal', 'Trust', 'SWC', 'None'],
#       dtype=object)

# %%
dataset['funder'].fillna(dataset['funder'].mode()[0], inplace=True)

# %%
dataset['installer'].fillna(dataset['installer'].mode()[0], inplace=True)

# %% [markdown]
# ### Finding the Percentage of Missing Values

# %%
# Find percentage of missing values.
(dataset.isnull().sum().sort_index()/len(dataset))
# Out:
# age_of_pump                 0.0
# amount_tsh                  0.0
# basin                       0.0
# construction_year           0.0
# day_of_week_recorded        0.0
# day_of_year_recorded        0.0
# district_code               0.0
# extraction_type             0.0
# extraction_type_class       0.0
# extraction_type_group       0.0
# funder                      0.0
# geometry                    0.0
# gps_height                  0.0
# id                          0.0
# installer                   0.0
# lga                         0.0
# management                  0.0
# management_group            0.0
# month_recorded              0.0
# num_private                 0.0
# payment                     0.0
# payment_type                0.0
# permit                      0.0
# population                  0.0
# public_meeting              0.0
# quality_group               0.0
# quantity                    0.0
# quantity_group              0.0
# quarter_of_date_recorded    0.0
# ...

# %%
# Check for missing values again.
(dataset.isnull().sum().sort_index()/len(dataset))
# Out:
# age_of_pump                 0.0
# amount_tsh                  0.0
# basin                       0.0
# construction_year           0.0
# day_of_week_recorded        0.0
# day_of_year_recorded        0.0
# district_code               0.0
# extraction_type             0.0
# extraction_type_class       0.0
# extraction_type_group       0.0
# funder                      0.0
# geometry                    0.0
# gps_height                  0.0
# id                          0.0
# installer                   0.0
# lga                         0.0
# management                  0.0
# management_group            0.0
# month_recorded              0.0
# num_private                 0.0
# payment                     0.0
# payment_type                0.0
# permit                      0.0
# population                  0.0
# public_meeting              0.0
# quality_group               0.0
# quantity                    0.0
# quantity_group              0.0
# quarter_of_date_recorded    0.0
# ...

# %%
# pct of cells with missing values out of all cells
total_cells = np.product(dataset.shape)
total_missing_values = dataset.isnull().sum().sum()
pct_missing = (total_missing_values / total_cells * 100)
print("Percentage of cells with null-values: {0:.1f}%".format(pct_missing))
# Out:
# Percentage of cells with null-values: 0.0%

# %%
# Drop columns with a very high distinct count of unique values.
dataset.drop(['funder', 'installer', 'lga', 'scheme_name', 'subvillage', 'ward', 'wpt_name'], axis=1, inplace=True)

# %% [markdown]
# ## Exploring the Categorical Features

# %%
print("Funder contains {} unique entities that have funded wells in Tanzania.".format(len(dataset.funder.unique())))
print("\nCount of each funder in the dataset:\n{}".format(dataset.funder.value_counts()))
# Out:
# Funder contains 1897 unique entities that have funded wells in Tanzania.
#
# Count of each funder in the dataset:
# Government Of Tanzania         12719
# Danida                          3114
# Hesawa                          2202
# Rwssp                           1374
# World Bank                      1349
# Kkkt                            1287
# World Vision                    1246
# Unicef                          1057
# Tasaf                            877
# District Council                 843
# Dhv                              829
# Private Individual               826
# Dwsp                             811
# 0                                777
# Norad                            765
# Germany Republi                  610
# Tcrs                             602
# Ministry Of Water                590
# Water                            583
# Dwe                              484
# Netherlands                      470
# Hifab                            450
# ...

# %% [markdown]
# Notice there are 777 observations of "0" likely to represent a null-value. This is in addition to the null-values and would need to be cleaned in the data cleaning section.

# %%
print("Installer contains {} unique entities with the name of the organisation that installed the well.".format(len(dataset.installer.unique())))
print("\nCount of each installer in the dataset:\n{}".format(dataset.installer.value_counts()))
# Out:
# Installer contains 2145 unique entities with the name of the organisation that installed the well.
#
# Count of each installer in the dataset:
# DWE                          21057
# Government                    1825
# RWE                           1206
# Commu                         1060
# DANIDA                        1050
# KKKT                           898
# Hesawa                         840
# 0                              777
# TCRS                           707
# Central government             622
# CES                            610
# Community                      553
# DANID                          552
# District Council               551
# HESAWA                         539
# World vision                   408
# LGA                            408
# WEDECO                         397
# TASAF                          396
# District council               392
# Gover                          383
# AMREF                          329
# TWESA                          316
# ...

# %%
print("Subvillage contains {} unique entities with the geographic location of the wells.".format(len(dataset.subvillage.unique())))
print("\nCount of each subvillage in the dataset:\n{}".format(dataset.subvillage.value_counts()))
# Out:
# Subvillage contains 19287 unique entities with the geographic location of the wells.
#
# Count of each subvillage in the dataset:
# Madukani          879
# Shuleni           506
# Majengo           502
# Kati              373
# Mtakuja           262
# Sokoni            232
# M                 187
# Muungano          172
# Mbuyuni           164
# Mlimani           152
# Songambele        147
# Miembeni          134
# Msikitini         134
# 1                 132
# Kibaoni           114
# Kanisani          111
# Mapinduzi         109
# I                 109
# Mjini             108
# Mjimwema          108
# Mkwajuni          104
# Mwenge            102
# Mabatini           98
# Azimio             98
# Mission            95
# Mbugani            95
# Bwawani            91
# Bondeni            90
# Chang'Ombe         88
# Zahanati           86
#                  ...
# Humbo               1
# Nyailungu           1
# Likweje A           1
# Mwamagiri           1
# Bulanda             1
# ...

# %%
print("Public_meeting contains {} unique entities evaluating to either True/False or null-value.".format(len(dataset.public_meeting.unique())))
print("\nCount of each public_meeting in the dataset:\n{}".format(dataset.public_meeting.value_counts()))
# Out:
# Public_meeting contains 2 unique entities evaluating to either True/False or null-value.
#
# Count of each public_meeting in the dataset:
# True     54345
# False     5055
# Name: public_meeting, dtype: int64

# %%
sns.countplot(data=dataset, x='public_meeting', hue='status_group')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
print("Scheme_management contains {} unique entities with the names of who operates the waterpoints.".format(len(dataset.scheme_management.unique())))
print("\nCount of each scheme_management in the dataset:\n{}".format(dataset.scheme_management.value_counts()))
# Out:
# Scheme_management contains 12 unique entities with the names of who operates the waterpoints.
#
# Count of each scheme_management in the dataset:
# VWC                 40670
# WUG                  5206
# Water authority      3153
# WUA                  2883
# Water Board          2748
# Parastatal           1680
# Private operator     1063
# Company              1061
# Other                 766
# SWC                    97
# Trust                  72
# None                    1
# Name: scheme_management, dtype: int64

# %%
sns.countplot(data=dataset, x='scheme_management', hue='status_group')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# While scheme_management and scheme_name appear to have the same column description their values are not identical.

# %%
print("Scheme_name contains {} unique entities with the names of who operates the waterpoints.".format(len(dataset.scheme_name.unique())))
print("\nCount of each scheme_name in the dataset:\n{}".format(dataset.scheme_name.value_counts()))
# Out:
# Scheme_name contains 2696 unique entities with the names of who operates the waterpoints.
#
# Count of each scheme_name in the dataset:
# K                                                 28848
# None                                                644
# Borehole                                            546
# Chalinze wate                                       405
# M                                                   400
# DANIDA                                              379
# Government                                          320
# Ngana water supplied scheme                         270
# wanging'ombe water supply s                         261
# wanging'ombe supply scheme                          234
# I                                                   229
# Bagamoyo wate                                       229
# Uroki-Bomang'ombe water sup                         209
# N                                                   204
# ...

# %%
print("Permit contains {} unique entities indicating whether waterpoints had permits".format(len(dataset.permit.unique())))
print("\nCount of each permit in the dataset:\n{}".format(dataset.permit.value_counts()))
# Out:
# Permit contains 2 unique entities indicating whether waterpoints had permits
#
# Count of each permit in the dataset:
# True     41908
# False    17492
# Name: permit, dtype: int64

# %%
sns.countplot(data=dataset, x='permit', hue='status_group')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# The net amount of waterpoints that are functional, non-functional and functional but needs repair are around twice as high for waterpoints that have a permit compared to those that don't. This means we have more data on waterpoints with a permit than those without.

# %%
sns.countplot(data=dataset, x='permit', hue='status_group')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# The net amount of waterpoints that are functional, non-functional and functional but needs repair are around twice as high for waterpoints that have a permit compared to those that don't. This means we have more data on waterpoints with a permit than those without.

# %% [markdown]
# ## Exploring the Numerical Features

# %%
labels_count = dataset.status_group.value_counts()
total_labels = dataset.status_group.count()
(labels_count/total_labels)

# %%
sns.heatmap(dataset.corr(), square=True, cmap='RdYlGn')
